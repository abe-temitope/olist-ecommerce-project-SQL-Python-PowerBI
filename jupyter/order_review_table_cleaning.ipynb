# %%
import pandas as pd

df = pd.read_csv(
    r"C:\ProgramData\MySQL\MySQL Server 8.0\Uploads\olist_ecommerce_data\olist_order_reviews_dataset.csv",
    sep=",",
    quotechar='"',
    engine="python"
)

# %%
df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
print("Rows loaded:", len(df))
# Out:
# Rows loaded: 99223

# %%
duplicates_id = df[df.duplicated(subset="review_id", keep=False)]
duplicates_id.sort_values("review_id")
# Out:
#                               review_id                          order_id  \
# 29840  00130cbe1f9d422698c812ed8ded1919  04a28263e085d399c97ae49e0b477efa
# 46677  00130cbe1f9d422698c812ed8ded1919  dfcdfc43867d1c1381bfaf62d6b9c195
# 63192  0115633a9c298b6a98bcbe4eee75345f  0c9850b2c179c1ef60d2855e2751d1fa
# 90676  0115633a9c298b6a98bcbe4eee75345f  78a4201f58af3463bdab842eea4bc801
# 92875  0174caf0ee5964646040cd94e15ac95e  f93a732712407c02dce5dd5088d0f47b
# ...                                 ...                               ...
# 31119  fe5c833752953fed3209646f1f63b53c  4863e15fa53273cc7219c58f5ffda4fb
# 7869   ff2fc9e68f8aabfbe18d710b83aabd30  2da58e0a7dcfa4ce1e00fad9d03ca3b5
# 82520  ff2fc9e68f8aabfbe18d710b83aabd30  1078d496cc6ab9a8e6f2be77abf5091b
# 73950  ffb8cff872a625632ac983eb1f88843c  c44883fc2529b4aa03ca90e7e09d95b6
# 1985   ffb8cff872a625632ac983eb1f88843c  c88b1d1b157a9999ce368f218a407141
#
#        review_score review_comment_title  \
# 29840             1                  NaN
# 46677             1                  NaN
# 63192             5                  NaN
# 90676             5                  NaN
# 92875             1                  NaN
# ...             ...                  ...
# 31119             1                  NaN
# 7869              2                  NaN
# 82520             2                  NaN
# 73950             3                  NaN
# 1985              3                  NaN
#
#                                   review_comment_message review_creation_date  \
# 29840  O cartucho "original HP" 60XL não é reconhecid...  2018-03-07 00:00:00
# 46677  O cartucho "original HP" 60XL não é reconhecid...  2018-03-07 00:00:00
# 63192                                                NaN  2017-09-21 00:00:00
# 90676                                                NaN  2017-09-21 00:00:00
# 92875  Produto entregue dentro de embalagem do fornec...  2018-03-07 00:00:00
# ...                                                  ...                  ...
# 31119  Comprei dois produtos e ambos, mesmo enviados ...  2018-02-28 00:00:00
# 7869                                                 NaN  2018-03-17 00:00:00
# 82520                                                NaN  2018-03-17 00:00:00
# 73950                                                NaN  2017-07-22 00:00:00
# 1985                                                 NaN  2017-07-22 00:00:00
#
#       review_answer_timestamp
# 29840     2018-03-20 18:08:23
# 46677     2018-03-20 18:08:23
# 63192     2017-09-26 03:27:47
# 90676     2017-09-26 03:27:47
# 92875     2018-03-08 03:00:53
# ...                       ...
# 31119     2018-02-28 13:57:52
# 7869      2018-03-19 11:44:15
# 82520     2018-03-19 11:44:15
# 73950     2017-07-26 13:41:07
# 1985      2017-07-26 13:41:07
#
# [1601 rows x 7 columns]

# %%
duplicates_full = df[df.duplicated(keep=False)]
print(duplicates_full)
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
df_clean = df.drop_duplicates(subset="review_id", keep="first")

# %%
print("Before:", len(df))
print("After:", len(df_clean))
# Out:
# Before: 99223
# After: 98410

# %%
df_clean.to_csv(
    r"C:\ProgramData\MySQL\MySQL Server 8.0\Uploads\olist_ecommerce_data\olist_order_reviews_final.csv",
    index=False
)
